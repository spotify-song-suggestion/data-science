# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("https://github.com/spotify-song-suggestion/data-science/raw/main/csv/data.csv")

# %%
df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
gapminder = df
print(gapminder.head(3))
# Out:
#    acousticness                                   artists  ...  valence  year
# 0         0.995                       ['Carl Woitschach']  ...   0.7790  1928
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']  ...   0.0767  1928
# 2         0.604                   ['Seweryn Goszczyński']  ...   0.8800  1928
#
# [3 rows x 19 columns]

# %%
df1 = gapminder[['name', 'popularity','year']]
print(df1.head())
# Out:
#                                             name  popularity  year
# 0                    Singende Bataillone 1. Teil           0  1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0  1928
# 2                 Chapter 1.18 - Zamek kaniowski           0  1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0  1928
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1  1928

# %%
heatmap1_data = pd.pivot_table(df1, values='popularity', 
                               index=['name'], 
                               columns='year')
sns.heatmap(heatmap1_data, cmap="YlGnBu")

# %%
df['artists'] = df['artists'].str.strip('[]')
df
# Out:
#         acousticness                                 artists  ...  valence  year
# 0             0.9950                       'Carl Woitschach'  ...   0.7790  1928
# 1             0.9940  'Robert Schumann', 'Vladimir Horowitz'  ...   0.0767  1928
# 2             0.6040                   'Seweryn Goszczyński'  ...   0.8800  1928
# 3             0.9950                      'Francisco Canaro'  ...   0.7200  1928
# 4             0.9900  'Frédéric Chopin', 'Vladimir Horowitz'  ...   0.0693  1928
# ...              ...                                     ...  ...      ...   ...
# 169904        0.1730                    'DripReport', 'Tyga'  ...   0.3060  2020
# 169905        0.0167        'Leon Bridges', 'Terrace Martin'  ...   0.2700  2020
# 169906        0.5380                     'Kygo', 'Oh Wonder'  ...   0.1530  2020
# 169907        0.0714             'Cash Cash', 'Andy Grammer'  ...   0.4720  2020
# 169908        0.1090                        'Ingrid Andress'  ...   0.3660  2020
#
# ...

# %%
df['artists'] = df['artists'].str.replace("'", "")
df
# Out:
#         acousticness                             artists  ...  valence  year
# 0             0.9950                     Carl Woitschach  ...   0.7790  1928
# 1             0.9940  Robert Schumann, Vladimir Horowitz  ...   0.0767  1928
# 2             0.6040                 Seweryn Goszczyński  ...   0.8800  1928
# 3             0.9950                    Francisco Canaro  ...   0.7200  1928
# 4             0.9900  Frédéric Chopin, Vladimir Horowitz  ...   0.0693  1928
# ...              ...                                 ...  ...      ...   ...
# 169904        0.1730                    DripReport, Tyga  ...   0.3060  2020
# 169905        0.0167        Leon Bridges, Terrace Martin  ...   0.2700  2020
# 169906        0.5380                     Kygo, Oh Wonder  ...   0.1530  2020
# 169907        0.0714             Cash Cash, Andy Grammer  ...   0.4720  2020
# 169908        0.1090                      Ingrid Andress  ...   0.3660  2020
#
# [169909 rows x 19 columns]

# %%
df2 = gapminder[['popularity','name', 'year']]
heatmap2_data = pd.pivot_table(df2,values='popularity', index=['name'], columns='year')
heatmap2_data.head(n=5)
sns.heatmap(heatmap2_data, cmap="BuGn")

# %%
df3 = gapminder[['popularity','name', 'year','artists']]
heatmap3_data = pd.pivot_table(df3, values='popularity', index=['name'], columns='year')
plt.figure(figsize=(8, 20))
sns.heatmap(heatmap3_data, cmap="RdBu")

# %%
df3 = gapminder[['popularity','name', 'year','artists']]
heatmap3_data = pd.pivot_table(df3, values='popularity', index=['name'], columns='year')
plt.figure(figsize=(8, 20))
sns.heatmap(heatmap3_data, cmap="RdBu")

# %%
current_year = 2020
dff = df[df['year'].eq(current_year)].sort_values(by='popularity', ascending=False).head(10)
dff
# Out:
#        acousticness                             artists  ...  valence  year
# 87942       0.00146                          The Weeknd  ...    0.334  2020
# 87940       0.24700                 DaBaby, Roddy Ricch  ...    0.497  2020
# 87949       0.73100                  Powfu, beabadoobee  ...    0.348  2020
# 87941       0.23300  THE SCOTTS, Travis Scott, Kid Cudi  ...    0.280  2020
# 87946       0.32100                               Drake  ...    0.837  2020
# 87943       0.74900                      StaySolidRocky  ...    0.629  2020
# 87951       0.02640                             6ix9ine  ...    0.393  2020
# 87952       0.02100            Lady Gaga, Ariana Grande  ...    0.646  2020
# 87953       0.22300        Ariana Grande, Justin Bieber  ...    0.537  2020
# 87944       0.01700                         Jack Harlow  ...    0.826  2020
#
# [10 rows x 19 columns]

# %%
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML
df1 = gapminder[['name', 'popularity','year']]
current_year = 2020
dff = df1[df1['year'].eq(current_year)].sort_values(by='popularity', ascending=False).head(10)
dff
# Out:
#                                                     name  popularity  year
# 87942                                    Blinding Lights         100  2020
# 87940                       ROCKSTAR (feat. Roddy Ricch)          99  2020
# 87949  death bed (coffee for your head) (feat. beabad...          97  2020
# 87941                                         THE SCOTTS          96  2020
# 87946                                       Toosie Slide          95  2020
# 87943                                         Party Girl          94  2020
# 87951                                              GOOBA          94  2020
# 87952                    Rain On Me (with Ariana Grande)          94  2020
# 87953                  Stuck with U (with Justin Bieber)          94  2020
# 87944                                       WHATS POPPIN          92  2020

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax.barh(dff['name'], dff['popularity'])
# Out:
# <BarContainer object of 10 artists>

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Spotify Feature Correlation')
    labels=['name','artists','year','popularity','danceability',  'instrumentalness', 'loudness', 'speechiness',  'valence']
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=9)

    plt.show()

correlation_matrix(df)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

#df2 = gapminder[['popularity','name', 'year']]
#heatmap2_data = pd.pivot_table(df2,values='popularity', index=['name'], columns='year')
#heatmap2_data.head(n=5)
#sns.heatmap(heatmap2_data, cmap="BuGn")

N_numbers = 100000
N_bins = 100

np.random.seed(0)

x, y = np.random.multivariate_normal(
        mean=[0.0, 0.0],      
        cov=[[1.0, 0.4],
             [0.4, 0.25]],    
        size=N_numbers
        ).T                  


plt.hist2d(x, y, bins=N_bins, normed=False, cmap='plasma')

cb = plt.colorbar()
cb.set_label('Number of entries')

plt.title('Heatmap of 2D normally distributed data points')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning: The 'normed' parameter of hist2d() has been renamed 'density' since Matplotlib 3.1; support for the old name will be dropped in 3.3.

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

N_numbers = 100000
N_bins = 20

np.random.seed(0)


x, y = np.random.multivariate_normal(
        mean=[0.0, 0.0],    
        cov=[[1.0, 0.4],
             [0.4, 0.25]],    
        size=N_numbers
        ).T                   

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(x, y, bins=N_bins)

plt.title('3D histogram of 2D normally distributed data points')
plt.xlabel('x axis')
plt.ylabel('y axis')


xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25)
xpos = xpos.flatten('F')
ypos = ypos.flatten('F')
zpos = np.zeros_like(xpos)

dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y = np.random.rand(2, 100) * 4
hist, xedges, yedges = np.histogram2d(x, y, bins=4, range=[[0, 4], [0, 4]])


xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25)
xpos = xpos.flatten('F')
ypos = ypos.flatten('F')
zpos = np.zeros_like(xpos)


dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()

# %%
df6 = gapminder[['popularity','name', 'year','artists']]
heatmap3_data = pd.pivot_table(dff, values='popularity', index=['name'], columns='year')
plt.figure(figsize=(8, 20))
plt.title('Top 10 Heatmap')
sns.heatmap(heatmap3_data, cmap="RdBu")

# %%
df.shape
# Out:
# (169909, 19)

# %%
df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
couple_columns = df[['name','popularity', 'year']]
couple_columns.head()
# Out:
#                                             name  popularity  year
# 0                    Singende Bataillone 1. Teil           0  1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0  1928
# 2                 Chapter 1.18 - Zamek kaniowski           0  1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0  1928
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1  1928

# %%
df.shape
# Out:
# (169909, 19)

# %%
df.head()
# Out:
#    acousticness                             artists  ...  valence  year
# 0         0.995                     Carl Woitschach  ...   0.7790  1928
# 1         0.994  Robert Schumann, Vladimir Horowitz  ...   0.0767  1928
# 2         0.604                 Seweryn Goszczyński  ...   0.8800  1928
# 3         0.995                    Francisco Canaro  ...   0.7200  1928
# 4         0.990  Frédéric Chopin, Vladimir Horowitz  ...   0.0693  1928
#
# [5 rows x 19 columns]

# %%
df = df.reset_index()
df.head()
# Out:
#    index  acousticness  ... valence  year
# 0      0         0.995  ...  0.7790  1928
# 1      1         0.994  ...  0.0767  1928
# 2      2         0.604  ...  0.8800  1928
# 3      3         0.995  ...  0.7200  1928
# 4      4         0.990  ...  0.0693  1928
#
# [5 rows x 20 columns]

# %%
major_ticks = np.arange(0, 10, 2)                                              
minor_ticks = np.arange(0, 5, 2)  

fig = plt.figure(figsize = (15,10))  
ax = fig.add_subplot(1,1,1) 
s = ax.scatter('tempo', 'loudness', c = 'popularity',data = df, cmap = 'Blues_r', marker = 's',s = 10)
ax.axis([df['tempo'].min()-10, df['tempo'].max()+5, df['loudness'].min()-10, df['loudness'].max()+5])
ax.set_xticks(major_ticks)                                                       
ax.set_xticks(minor_ticks, minor=True)                                           
ax.set_yticks(major_ticks)                                                                                                                                                      
ax.grid(which='both', alpha = .5)                                                                                                           
ax.grid(which='major', alpha= .5) 
ax.set_xlabel('tempo', fontsize=10);
ax.set_ylabel('loudness', fontsize=10);
ax.set_title('Loudness and Tempo', size = 15)

# http://stackoverflow.com/questions/13943217/how-to-add-colorbars-to-scatterplots-created-like-this
cbar = plt.colorbar(mappable = s,ax = ax)

plt.show()
